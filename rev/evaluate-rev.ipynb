# %%
import pandas as pd

# %%
df_rationale = pd.read_json('learned-NQ-test-rationale-predicted.jsonl', lines=True)

# %%
df_rationale
# Out:
#        qid                                           question  \
# 0        1  which mode is used for short wave broadcast se...
# 1        1  which mode is used for short wave broadcast se...
# 2        1  which mode is used for short wave broadcast se...
# 3        1  which mode is used for short wave broadcast se...
# 4        1  which mode is used for short wave broadcast se...
# ...    ...                                                ...
# 7545  3017  character in macbeth who is murdered and appea...
# 7546  3017  character in macbeth who is murdered and appea...
# 7547  3017  character in macbeth who is murdered and appea...
# 7548  3017  character in macbeth who is murdered and appea...
# 7549  3017  character in macbeth who is murdered and appea...
#
#            golden_answer   system  \
# 0            Olivia/MFSK    gpt35
# 1            Olivia/MFSK  chatgpt
# 2            Olivia/MFSK     gpt4
# 3            Olivia/MFSK  newbing
# 4            Olivia/MFSK      fid
# ...
